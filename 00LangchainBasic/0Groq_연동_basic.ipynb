# %%
print("Hello LangChain")
# Out:
# Hello LangChain

# %%
import os
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI 


load_dotenv(dotenv_path='../.env')
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_O

# %%
# prompt + llm + output 

# prompt
prompt = ChatPromptTemplate.from_messages(
    [ ("system", "당신은 개발자입니다.") , 
     ("user", "{input}") ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
prompt_text = prompt.format(input="파이썬은 무엇인가요? 자세하게 설명해주세요")

# %%
#llm = ChatOpenAI(api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-0125")

# Groq API를 사용하는 ChatOpenAI 인스턴스 생성
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000115C4C03A70>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000115C4D31160>, root_client=<openai.OpenAI object at 0x00000115C47BF2C0>, root_async_client=<openai.AsyncOpenAI object at 0x00000115C4C00A70>, model_name='meta-llama/llama-4-scout-17b-16e-instruct', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://api.groq.com/openai/v1')

# %%
try:
    response = llm.invoke(prompt_text)
    print("응답:", response.content)
except Exception as e:
    print(f"오류 발생: {e}")
# Out:
# 응답: 파이썬! 프로그래밍 세계에서 매우 인기 있는 언어입니다. 파이썬은 1991년 Guido van Rossum에 의해 개발된 고급 프로그래밍 언어입니다. 이 언어는 배우기 쉽고, 다양한 응용 프로그램 개발에 사용할 수 있습니다.
#
# **파이썬의 특징**
#
# 1. **쉬운 학습 곡선**: 파이썬은 매우 직관적이고 읽기 쉬운 문법을 가지고 있습니다. 따라서 초보자들이 프로그래밍을 시작할 때 좋은 선택입니다.
# 2. **다목적**: 파이썬은 웹 개발, 데이터 분석, 인공지능, 과학 컴퓨팅, 자동화 등 다양한 분야에서 사용할 수 있습니다.
# 3. **대규모 라이브러리**: 파이썬은 방대한 라이브러리와 모듈을 보유하고 있습니다. 이를 통해 개발자들은 쉽게 기능을 추가하고 확장할 수 있습니다.
# 4. **플랫폼 독립성**: 파이썬은 Windows, macOS, Linux 등 다양한 운영 체제에서 실행할 수 있습니다.
# 5. **오픈 소스**: 파이썬은 오픈 소스 언어입니다. 즉, 누구나 무료로 사용할 수 있으며, 소스코드를 수정하고 배포할 수 있습니다.
#
# **파이썬의 응용 분야**
#
# 1. **웹 개발**: 파이썬은 웹 개발을 위해 Django, Flask 등 다양한 프레임워크를 제공합니다.
# 2. **데이터 분석**: 파이썬은 NumPy, pandas, scikit-learn 등 다양한 라이브러리를 통해 데이터 분석과 머신러닝에 사용됩니다.
# 3. **인공지능**: 파이썬은 TensorFlow, Keras 등 다양한 라이브러리를 통해 인공지능과 딥러닝에 사용됩니다.
# 4. **과학 컴퓨팅**: 파이썬은 과학 컴퓨팅을 위해 NumPy, SciPy 등 다양한 라이브러리를 제공합니다.
# 5. **자동화**: 파이썬은 자동화를 위해 다양한 라이브러리와 모듈을 제공합니다.
#
# **파이썬의 버전**
#
# 파이썬은 크게 두 가지 버전으로 나뉩니다.
#
# 1. **파이썬 2.x**: 파이썬 2.x는 2000년에 출시되었으며, 2020년에 지원이 종료되었습니다.
# 2. **파이썬 3.x**: 파이썬 3.x는 2008년에 출시되었으며, 현재 가장 최신의 버전입니다.
#
# **결론**
#
# 파이썬은 쉽고 강력한 프로그래밍 언어입니다. 다양한 응용 분야에서 사용할 수 있으며, 대규모 라이브러리와 모듈을 보유하고 있습니다. 따라서 파이썬은 초보자와 숙련된 개발자 모두에게 좋은 선택입니다.

# %% [markdown]
# # LCEL

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser
print(chain)
# Out:
# first=ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]) middle=[ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000115C4C03A70>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000115C4D31160>, root_client=<openai.OpenAI object at 0x00000115C47BF2C0>, root_async_client=<openai.AsyncOpenAI object at 0x00000115C4C00A70>, model_name='meta-llama/llama-4-scout-17b-16e-instruct', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://api.groq.com/openai/v1')] last=StrOutputParser()

# %%
response = chain.invoke({"input":"지구의 자전주기는 얼마인가요?"})

# %%
print(response)
# Out:
# 지구의 자전주기는 24시간입니다. 이를 지구의 날이라고도 합니다.
