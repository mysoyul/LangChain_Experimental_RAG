# %%
import os
import time
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI 

# 환경변수 로드
load_dotenv(dotenv_path='../.env')
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# LLM 모델 설정
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    temperature=0.7
)
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x000002A59034B800> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002A5901BBB30> root_client=<openai.OpenAI object at 0x000002A58FE07FB0> root_async_client=<openai.AsyncOpenAI object at 0x000002A59034B860> model_name='meta-llama/llama-4-scout-17b-16e-instruct' temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://api.groq.com/openai/v1'

# %%
print("="*60)
print("프롬프트 개선 전후 비교 분석")
print("="*60)

# 분석할 주제
topic = "머신러닝"

# ========================================
# 1. 기본 프롬프트 (개선 전)
# ========================================
print("\n 기본 프롬프트 (개선 전)")
print("-" * 40)

# 기본 프롬프트 생성
basic_prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 도움이 되는 AI 어시스턴트입니다."),
    ("user", "{topic}에 대해 설명해주세요.")
])

print(" 기본 프롬프트 구조:")
print(basic_prompt)

# 기본 프롬프트 포맷팅
basic_prompt_text = basic_prompt.format(topic=topic)
print(f"\n 실제 전송 메시지:\n{basic_prompt_text}")

# 기본 프롬프트 실행
print("\n 기본 프롬프트 실행 중...")
start_time = time.time()

try:
    basic_response = llm.invoke(basic_prompt_text)
    basic_time = time.time() - start_time
    
    print(f"\n 기본 프롬프트 응답 (소요시간: {basic_time:.2f}초):")
    print("-" * 30)
    print(basic_response.content)
    
    # 기본 응답 분석
    basic_length = len(basic_response.content)
    basic_word_count = len(basic_response.content.split())
    print(f"\n 기본 응답 분석:")
    print(f"   - 응답 길이: {basic_length}자")
    print(f"   - 단어 수: {basic_word_count}개")
    print(f"   - 소요 시간: {basic_time:.2f}초")
    
except Exception as e:
    print(f" 기본 프롬프트 오류: {e}")
    basic_response = None
    basic_time = 0
    basic_length = 0
    basic_word_count = 0
# Out:
# ============================================================
# 프롬프트 개선 전후 비교 분석
# ============================================================
#
#  기본 프롬프트 (개선 전)
# ----------------------------------------
#  기본 프롬프트 구조:
# input_variables=['topic'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 도움이 되는 AI 어시스턴트입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic}에 대해 설명해주세요.'), additional_kwargs={})]
#
#  실제 전송 메시지:
# System: 당신은 도움이 되는 AI 어시스턴트입니다.
# Human: 머신러닝에 대해 설명해주세요.
#
#  기본 프롬프트 실행 중...
#
#  기본 프롬프트 응답 (소요시간: 1.51초):
# ------------------------------
# 머신러닝은 인공지능(AI)의 한 분야로, 컴퓨터가 데이터를 학습하고 예측하거나 결정을 내릴 수 있도록 하는 기술입니다. 머신러닝은 전통적인 프로그래밍 방식과 달리, 컴퓨터가 스스로 데이터를 분석하고 패턴을 찾아내어 학습합니다.
#
# 머신러닝의 기본 개념은 다음과 같습니다.
#
# 1. **데이터**: 머신러닝은 데이터를 기반으로 학습합니다. 데이터는 입력(input)과 출력(output)의 쌍으로 구성되며, 이를 통해 컴퓨터는 패턴을 학습합니다.
# 2. **모델**: 머신러닝 모델은 데이터를 학습하고 예측하거나 결정을 내리는 알고리즘입니다. 모델은 데이터를 기반으로 학습되며, 학습된 모델은 새로운 데이터에 대해 예측이나 결정을 내릴 수 있습니다.
# 3. **학습**: 머신러닝의 핵심은 학습입니다. 컴퓨터는 데이터를 학습하여 모델을 만들고, 이 모델을 통해 새로운 데이터에 대해 예측이나 결정을 내립니다.
#
# 머신러닝에는 여러 가지 유형이 있습니다.
#
# 1. **감독 학습(Supervised Learning)**: 레이블이 있는 데이터를 사용하여 모델을 학습하는 방식입니다. 예를 들어, 이미지 분류 문제에서 이미지에 대한 레이블(예: 고양이, 강아지)을 제공하고 모델을 학습합니다.
# 2. **비감독 학습(Unsupervised Learning)**: 레이블이 없는 데이터를 사용하여 모델을 학습하는 방식입니다. 예를 들어, 고객 세분화 문제에서 고객 데이터만 제공하고 모델을 학습하여 유사한 고객 그룹을 찾습니다.
# 3. **강화 학습(Reinforcement Learning)**: 에이전트가 환경과 상호작용하며 보상을 최대화하는 방식으로 학습하는 방식입니다. 예를 들어, 로봇이 미로를 빠져나오는 문제를 해결하기 위해 강화 학습을 사용할 수 있습니다.
#
# 머신러닝은 다양한 분야에서 응용되고 있습니다.
#
# 1. **이미지 인식**: 얼굴 인식, 객체 탐지, 이미지 분류 등
# 2. **자연어 처리**: 언어 번역, 감정 분석, 텍스트 분류 등
# 3. **추천 시스템**: 상품 추천, 콘텐츠 추천 등
# 4. **예측 분석**: 금융, 의료, 제조 등 다양한 분야에서 예측 분석을 위해 사용됩니다.
#
# 머신러닝은 데이터의 품질과 양에 크게 의존하며, 학습 데이터가 많고 다양할수록 더 정확한 모델을 만들 수 있습니다. 또한, 머신러닝 모델은 지속적으로 학습하고 업데이트되어야 하며, 이를 통해 성능을 개선할 수 있습니다.
#
#  기본 응답 분석:
#    - 응답 길이: 1178자
#    - 단어 수: 244개
#    - 소요 시간: 1.51초

# %%
# ========================================
# 2. 개선된 프롬프트 (개선 후)
# ========================================
print("\n" + "="*60)
print(" 개선된 프롬프트 (개선 후)")
print("-" * 40)

# 개선된 프롬프트 생성
improved_prompt = ChatPromptTemplate.from_messages([
    ("system", """당신은 친절하고 전문적인 교육 전문가입니다. 
복잡한 개념을 쉽게 설명하는 것이 특기이며, 
학습자가 이해하기 쉽도록 체계적으로 설명합니다."""),
    ("user", """주제: {topic}

다음 구조로 자세히 설명해주세요:

1.  간단한 정의 (한 문장으로)
2.  핵심 특징 3가지
3.  실생활 적용 사례 2가지  
4.  초보자를 위한 학습 팁
5.  향후 전망

각 섹션을 명확히 구분하고, 전문용어는 쉽게 풀어서 설명해주세요.
구체적인 예시를 포함하여 이해하기 쉽게 작성해주세요.""")
])

print(" 개선된 프롬프트 구조:")
print(improved_prompt)

# 개선된 프롬프트 포맷팅
improved_prompt_text = improved_prompt.format(topic=topic)
print(f"\n 실제 전송 메시지:\n{improved_prompt_text}")

# 개선된 프롬프트 실행
print("\n 개선된 프롬프트 실행 중...")
start_time = time.time()

try:
    improved_response = llm.invoke(improved_prompt_text)
    improved_time = time.time() - start_time
    
    print(f"\n 개선된 프롬프트 응답 (소요시간: {improved_time:.2f}초):")
    print("-" * 30)
    print(improved_response.content)
    
    # 개선된 응답 분석
    improved_length = len(improved_response.content)
    improved_word_count = len(improved_response.content.split())
    print(f"\n 개선된 응답 분석:")
    print(f"   - 응답 길이: {improved_length}자")
    print(f"   - 단어 수: {improved_word_count}개")
    print(f"   - 소요 시간: {improved_time:.2f}초")
    
except Exception as e:
    print(f" 개선된 프롬프트 오류: {e}")
    improved_response = None
    improved_time = 0
    improved_length = 0
    improved_word_count = 0
# Out:
# ============================================================
#  개선된 프롬프트 (개선 후)
# ----------------------------------------
#  개선된 프롬프트 구조:
# input_variables=['topic'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 친절하고 전문적인 교육 전문가입니다. \n복잡한 개념을 쉽게 설명하는 것이 특기이며, \n학습자가 이해하기 쉽도록 체계적으로 설명합니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='주제: {topic}\n\n다음 구조로 자세히 설명해주세요:\n\n1.  간단한 정의 (한 문장으로)\n2.  핵심 특징 3가지\n3.  실생활 적용 사례 2가지  \n4.  초보자를 위한 학습 팁\n5.  향후 전망\n\n각 섹션을 명확히 구분하고, 전문용어는 쉽게 풀어서 설명해주세요.\n구체적인 예시를 포함하여 이해하기 쉽게 작성해주세요.'), additional_kwargs={})]
#
#  실제 전송 메시지:
# System: 당신은 친절하고 전문적인 교육 전문가입니다.
# 복잡한 개념을 쉽게 설명하는 것이 특기이며,
# 학습자가 이해하기 쉽도록 체계적으로 설명합니다.
# Human: 주제: 머신러닝
#
# 다음 구조로 자세히 설명해주세요:
#
# 1.  간단한 정의 (한 문장으로)
# 2.  핵심 특징 3가지
# 3.  실생활 적용 사례 2가지
# 4.  초보자를 위한 학습 팁
# 5.  향후 전망
#
# 각 섹션을 명확히 구분하고, 전문용어는 쉽게 풀어서 설명해주세요.
# 구체적인 예시를 포함하여 이해하기 쉽게 작성해주세요.
#
#  개선된 프롬프트 실행 중...
#
#  개선된 프롬프트 응답 (소요시간: 1.87초):
# ------------------------------
# **1. 간단한 정의**
#
# 머신러닝은 컴퓨터가 데이터를 분석하고 학습하여 스스로 결정을 내릴 수 있도록 하는 인공지능(AI)의 한 분야입니다.
#
# **2. 핵심 특징 3가지**
#
# *   **데이터 기반 학습**: 머신러닝은 데이터를 분석하여 패턴을 발견하고, 이를 기반으로 학습합니다. 예를 들어, 사진 분류 모델은 수많은 사진을 보고 고양이와 강아지를 구분하는 법을 배웁니다.
# *   **예측 및 분류**: 학습된 모델을 통해 새로운 데이터를 예측하거나 분류할 수 있습니다. 예를 들어, 스팸 필터는 이메일을 학습된 패턴에 따라 스팸과 일반 이메일로 분류합니다.
# *   **자율 학습**: 머신러닝 모델은 새로운 데이터를 통해 지속적으로 학습하고 성능을 개선할 수 있습니다. 예를 들어, 자율 주행 자동차는 주행 중 수집된 데이터를 통해 운전 기술을 향상시킵니다.
#
# **3. 실생활 적용 사례 2가지**
#
# *   **추천 시스템**: 온라인 쇼핑몰이나 스트리밍 서비스에서 사용하는 추천 시스템은 사용자의 과거 구매 이력이나 시청 기록을 분석하여 맞춤형 상품이나 콘텐츠를 추천합니다. 예를 들어, 넷플릭스는 사용자가 시청한 영화와 비슷한 장르의 영화를 추천해 줍니다.
# *   **음성 인식**: 스마트폰의 음성 비서나 스마트 홈 기기에서 사용하는 음성 인식 기술은 사용자의 목소리를 분석하여 명령을 이해하고 실행합니다. 예를 들어, "헤이 구글, 날씨 알려줘"라고 말하면 현재 날씨를 알려줍니다.
#
# **4. 초보자를 위한 학습 팁**
#
# *   **기초 수학 학습**: 머신러닝은 선형 대수, 미적분, 확률과 통계와 같은 수학적 개념을 기반으로 합니다. 이러한 기초 수학을 학습하면 머신러닝 개념을 더 쉽게 이해할 수 있습니다.
# *   **프로그래밍 언어 학습**: 파이썬은 머신러닝에서 가장 많이 사용되는 프로그래밍 언어입니다. 파이썬을 학습하고, 텐서플로우나 사이킷런과 같은 머신러닝 라이브러리를 익히면 실제 머신러닝 모델을 구현할 수 있습니다.
# *   **실습 프로젝트 진행**: 이론만 학습하는 것보다 실제 데이터를 가지고 프로젝트를 진행하는 것이 중요합니다. Kaggle와 같은 플랫폼에서 제공하는 데이터 세트를 사용하여 다양한 머신러닝 모델을 구현해 보고, 결과를 분석해 보세요.
#
# **5. 향후 전망**
#
# *   **자율 주행 자동차**: 머신러닝은 자율 주행 자동차의 핵심 기술로, 차량이 도로 상황을 인식하고 안전하게 주행하는 데 중요한 역할을 합니다.
# *   **의료 진단**: 머신러닝은 의료 이미지 분석을 통해 질병을 진단하는 데 사용되고 있습니다. 예를 들어, 컴퓨터 비전 기술을 사용하여 X-ray나 MRI 이미지에서 암이나 기타 질병을 탐지할 수 있습니다. 이러한 기술은 의료 진단의 정확도를 높이고, 질병 조기 발견에 기여할 수 있습니다.
#
#  개선된 응답 분석:
#    - 응답 길이: 1379자
#    - 단어 수: 312개
#    - 소요 시간: 1.87초
