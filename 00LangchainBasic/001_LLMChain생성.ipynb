# %% [markdown]
# ### LLM Chain 만들기

# %% [markdown]
# ## 1. 환경 구성

# %% [markdown]
# ### 1) 라이브러리 설치

# %%
#%pip install -q langchain langchain-openai dotenv

# %% [markdown]
# ### 2) OpenAI 인증키 설정
# https://openai.com/

# %%
from dotenv import load_dotenv
import os
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv(dotenv_path='../.env')

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:2])
# Out:
# gs

# %%
import langchain
print(langchain.__version__)
# Out:
# 0.3.25

# %% [markdown]
# ## 2. LLM Chain

# %% [markdown]
# ### 1) Prompt + LLM

# %%
from langchain_openai import ChatOpenAI

# model
# llm = ChatOpenAI(model="gpt-3.5-turbo-0125")
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# chain 실행
result = llm.invoke("인공지능 모델의 학습 원리에 대하여 쉽게 설명해 주세요.")
print(type(result))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
print(type(result))
print(result)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# content='인공지능 모델의 학습 원리는 다음과 같습니다.\n\n1.  **데이터 수집**: 인공지능 모델을 학습시키기 위해서는 대량의 데이터가 필요합니다. 이 데이터는 문제의 유형에 따라 달라질 수 있습니다. 예를 들어, 이미지 인식 모델을 학습시키기 위해서는 이미지 데이터가 필요하고, 자연어 처리 모델을 학습시키기 위해서는 텍스트 데이터가 필요합니다.\n\n2.  **데이터 전처리**: 수집한 데이터를 모델에 입력하기 전에 전처리 과정을 거칩니다. 이 과정에서는 데이터를 정제하고, 변환하고, 필요한 경우 데이터를 확대하는 등의 작업을 수행합니다.\n\n3.  **모델 선택**: 인공지능 모델에는 여러 가지 유형이 있습니다. 예를 들어, 신경망 모델, 결정 트리 모델, 서포트 벡터 머신 모델 등이 있습니다. 각 모델은 특정 문제에 적합하며, 모델의 선택은 문제의 유형과 데이터의 특성에 따라 달라집니다.\n\n4.  **모델 학습**: 선택한 모델에 전처리한 데이터를 입력하여 모델을 학습시킵니다. 이 과정에서는 모델이 데이터를 분석하고, 패턴을 학습하며, 예측을 수행할 수 있도록 합니다.\n\n5.  **모델 평가**: 학습시킨 모델의 성능을 평가합니다. 이 과정에서는 모델의 예측 정확도, 오차율 등을 측정하여 모델의 성능을 평가합니다.\n\n6.  **모델 개선**: 모델의 성능이 만족할 만하지 않은 경우, 모델을 개선합니다. 이 과정에서는 모델의 구조를 변경하거나, 하이퍼파라미터를 조정하거나, 데이터를 추가하는 등의 작업을 수행합니다.\n\n7.  **모델 배포**: 학습시키고 평가한 모델을 실제 환경에 배포합니다. 이 과정에서는 모델을 API로 감싸거나, 모델을 파일로 저장하거나, 모델을 클라우드 서비스에 배포하는 등의 작업을 수행합니다.\n\n이러한 과정을 통해 인공지능 모델을 학습시키고, 배포할 수 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 382, 'prompt_tokens': 24, 'total_tokens': 406, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.061371387, 'prompt_time': 0.003180749, 'completion_time': 0.921955494, 'total_time': 0.925136243}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_79da0e0073', 'id': 'chatcmpl-235a3d21-dd9e-4a08-8b0a-83fd157a8b90', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None} id='run--39c16ba0-63d6-4edc-b15e-2365b5520cbf-0' usage_metadata={'input_tokens': 24, 'output_tokens': 382, 'total_tokens': 406, 'input_token_details': {}, 'output_token_details': {}}

# %%
print(result.content)
# Out:
# 인공지능 모델의 학습 원리는 다음과 같습니다.
#
# 1.  **데이터 수집**: 인공지능 모델을 학습시키기 위해서는 대량의 데이터가 필요합니다. 이 데이터는 문제의 유형에 따라 달라질 수 있습니다. 예를 들어, 이미지 인식 모델을 학습시키기 위해서는 이미지 데이터가 필요하고, 자연어 처리 모델을 학습시키기 위해서는 텍스트 데이터가 필요합니다.
#
# 2.  **데이터 전처리**: 수집한 데이터를 모델에 입력하기 전에 전처리 과정을 거칩니다. 이 과정에서는 데이터를 정제하고, 변환하고, 필요한 경우 데이터를 확대하는 등의 작업을 수행합니다.
#
# 3.  **모델 선택**: 인공지능 모델에는 여러 가지 유형이 있습니다. 예를 들어, 신경망 모델, 결정 트리 모델, 서포트 벡터 머신 모델 등이 있습니다. 각 모델은 특정 문제에 적합하며, 모델의 선택은 문제의 유형과 데이터의 특성에 따라 달라집니다.
#
# 4.  **모델 학습**: 선택한 모델에 전처리한 데이터를 입력하여 모델을 학습시킵니다. 이 과정에서는 모델이 데이터를 분석하고, 패턴을 학습하며, 예측을 수행할 수 있도록 합니다.
#
# 5.  **모델 평가**: 학습시킨 모델의 성능을 평가합니다. 이 과정에서는 모델의 예측 정확도, 오차율 등을 측정하여 모델의 성능을 평가합니다.
#
# 6.  **모델 개선**: 모델의 성능이 만족할 만하지 않은 경우, 모델을 개선합니다. 이 과정에서는 모델의 구조를 변경하거나, 하이퍼파라미터를 조정하거나, 데이터를 추가하는 등의 작업을 수행합니다.
#
# 7.  **모델 배포**: 학습시키고 평가한 모델을 실제 환경에 배포합니다. 이 과정에서는 모델을 API로 감싸거나, 모델을 파일로 저장하거나, 모델을 클라우드 서비스에 배포하는 등의 작업을 수행합니다.
#
# 이러한 과정을 통해 인공지능 모델을 학습시키고, 배포할 수 있습니다.

# %% [markdown]
# ### 2) PromptTemplate + LLM

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template("You are an expert in AI Expert. Answer the question. <Question>: {input}에 대해 쉽게 설명해주세요.")
prompt
# Out:
# PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='You are an expert in AI Expert. Answer the question. <Question>: {input}에 대해 쉽게 설명해주세요.')

# %%
from langchain_openai import ChatOpenAI

# llm = ChatOpenAI(model="gpt-3.5-turbo-0125")
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)
# chain 연결 (LCEL)
chain = prompt | llm
print(type(chain))

# chain 호출
result = chain.invoke({"input": "인공지능 모델의 학습 원리"})
print(type(result))
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
print(result.content)
# Out:
# 인공지능 모델의 학습 원리는 사람의 뇌가 학습하는 원리와 비슷하다고 할 수 있습니다. 우리의 뇌는 경험을 통해 배우고, 다음에 비슷한 상황이 발생했을 때 이전의 경험을 바탕으로 더 나은 결정을 내릴 수 있습니다. 인공지능 모델도 이와 유사한 방식으로 학습합니다.
#
# 1. **데이터 수집**: 인공지능 모델이 학습하기 위해서는大量的데이터가 필요합니다. 이 데이터는 과거의 경험이나 사례를 바탕으로 수집됩니다.
#
# 2. **데이터 처리**: 수집된 데이터는 전처리 과정을 거칩니다. 이 과정에서는 데이터의 품질을 높이고, 데이터의 특징을 추출하여 모델이 학습하기 쉽게 만드는 작업이 포함됩니다.
#
# 3. **모델 훈련**: 전처리된 데이터를 바탕으로 인공지능 모델을 훈련합니다. 이 과정에서는 모델이 데이터의 패턴이나 관계를 학습합니다. 모델은 예측을 하고, 실제 결과와 비교하여 오류를 계산합니다.
#
# 4. **오류 수정**: 모델의 예측과 실제 결과 사이의 오류를 줄이기 위해 모델의 매개변수를 조정합니다. 이 과정은 반복적으로 이루어지며, 모델의 성능이 개선됩니다.
#
# 5. **평가**: 일정 횟수만큼 훈련을 반복한 후, 모델의 성능을 평가합니다. 평가 과정에서는 모델이 새로운 데이터에 대해 얼마나 잘 작동하는지 확인합니다.
#
# 6. **튜닝**: 모델의 성능이 만족할 만한 수준이 아닐 경우, 하이퍼파라미터를 조정하거나 모델의 구조를 변경하여 추가적인 훈련을 진행합니다.
#
# 이를 통해 인공지능 모델은 주어진 데이터를 바탕으로 학습하고, 미래의 새로운 상황에 대해 예측하거나 결정을 내릴 수 있는 능력을 갖추게 됩니다. 이러한 학습 원리는 신경망, 딥러닝 등 다양한 유형의 인공지능 모델에 적용됩니다.

# %% [markdown]
# ### 3) PromptTemplate + LLM(invoke()) + StrOutputParser

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# 1. 컴포넌트 정의
prompt = PromptTemplate.from_template("You are an expert in AI Expert. Answer the question. <Question>: {input}에 대해 쉽게 설명해주세요.")

# llm = ChatOpenAI(model="gpt-3.5-turbo")
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

output_parser = StrOutputParser()

# 2. chain 생성 (LCEL)
chain = prompt | llm | output_parser
print(type(chain))

# 3. chain의 invoke 호출
result = chain.invoke({"input": "인공지능 모델의 학습 원리"})
print(type(result))
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# <class 'str'>

# %%
print(result)
# Out:
# 인공지능 모델의 학습 원리는 사람의 뇌가 학습하는 원리와 유사합니다. 컴퓨터가 데이터를 통해 배우고, 패턴을 발견하고, 예측이나 분류를 잘하도록 만드는 과정이라고 할 수 있습니다.
#
# 1. **데이터 수집**: 인공지능 모델을 학습시키기 위해서는 많은 양의 데이터가 필요합니다. 이 데이터는 문제에 따라 달라지며, 이미지, 텍스트, 오디오 등 다양한 형태가 될 수 있습니다.
#
# 2. **데이터 전처리**: 수집된 데이터는 모델에 사용하기 전에 전처리 과정을 거칩니다. 이 과정에서는 데이터의 잡음을 제거하거나, 데이터를 정규화하는 등의 작업을 수행하여 데이터의 품질을 높입니다.
#
# 3. **모델 선택**: 인공지능 모델에는 여러 종류가 있습니다. 예를 들어, 이미지 분류를 위해서는 합성곱 신경망(CNN), 자연어 처리를 위해서는 순환 신경망(RNN) 또는 트랜스포머 모델을 사용할 수 있습니다. 적합한 모델을 선택하는 것이 중요합니다.
#
# 4. **학습**: 선택된 모델에 데이터를 입력하고, 모델이 데이터를 학습합니다. 이 과정에서는 모델이 데이터의 패턴을 인식하고, 각 패턴에 따른 결과를 예측하도록 합니다. 학습 과정에서는 모델의 파라미터(가중치와 편향)를 조정하며, 이 조정 과정은 최적화 알고리즘에 의해 수행됩니다. 대표적인 최적화 알고리즘에는 경사 하강법(Gradient Descent)과 그 변형들이 있습니다.
#
# 5. **평가**: 모델이 학습된 후에는 테스트 데이터를 사용하여 모델의 성능을 평가합니다. 이 과정은 모델이 새로운, 보지 못한 데이터에 대해 얼마나 잘 작동하는지 확인하는 것입니다.
#
# 6. **튜닝**: 평가 결과에 따라 모델의 하이퍼파라미터를 조정하거나, 모델 구조를 변경하는 등의 작업을 수행하여 모델의 성능을 개선할 수 있습니다.
#
# 예를 들어, 어린 아이에게 고양이와 강아지의 사진을 여러 장 보여주고, 이 둘을 구별하도록 가르치는 것과 유사합니다. 처음에는 구별하지 못하지만, 여러 장의 사진을 보고, "이건 고양이야, 이건 강아지야"라는 말을 듣게 되면, 아이는 고양이와 강아지를 구별하는 법을 배우게 됩니다. 인공지능 모델도 이와 비슷한 방식으로 데이터를 통해 배우고, 패턴을 발견하고, 미래의 새로운 데이터를 분류하거나 예측하도록 학습합니다.

# %% [markdown]
# ### 4) PromptTemplate + LLM(stream()) + StrOutputParser

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# 1. 컴포넌트 정의
prompt = PromptTemplate.from_template("You are an expert in AI Expert. Answer the question. <Question>: {input}에 대해 쉽게 설명해주세요.")

#llm = ChatOpenAI(model="gpt-3.5-turbo-0125")
lm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# chain 연결 (LCEL)
chain = prompt | llm | StrOutputParser()

# 스트리밍 출력을 위한 요청
answer = chain.stream({"input": "인공지능 모델의 학습 원리"})
# 스트리밍 출력
#print(answer)

for token in answer:
    # 스트림에서 받은 데이터의 내용을 출력합니다. 줄바꿈 없이 이어서 출력하고, 버퍼를 즉시 비웁니다.
    print(token, end="", flush=True)

# %% [markdown]
# ##### 2) Multiple Chains
# * Multi Chain을 활용한 영화 추천 및 줄거리 요약

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# Step 1: 사용자가 입력한 장르에 따라 영화 추천
prompt1 = ChatPromptTemplate.from_template("{genre} 장르에서 추천할 만한 영화를 한 편 알려주세요.")

# Step 2: 추천된 영화의 줄거리를 요약
prompt2 = ChatPromptTemplate.from_template("{movie} 추천한 영화의 제목을 먼저 알려주시고, 줄을 바꾸어서 영화의 줄거리를 3문장으로 요약해 주세요.")

# OpenAI 모델 사용
# llm = ChatOpenAI(model="gpt-3.5-turbo-0125")
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# 체인 1: 영화 추천 (입력: 장르 → 출력: 영화 제목)
chain1 = prompt1 | llm | StrOutputParser()

# Step 1: 사용자가 입력한 장르에 따라 영화 추천
movie = chain1.invoke({"genre": "Drama"})  # 영화 제목 얻기
print(" 추천된 영화:", movie)  # movie 값 출력
# Out:
#  추천된 영화: 'The Pursuit of Happyness' (2006)
#
# 이 영화는 한 가난한 아버지가 자신의 꿈을 실현하고, 아들과 함께 안정된 삶을 만들기 위해 노력하는 과정을 그린 드라마입니다.
#
# 주인공인 크리스 가드너는 세일즈맨으로 일하면서도, 골드만삭스사에서 인턴으로 일할 기회를 얻기 위해 노력합니다.
#
# 그의 아들인 크리스토퍼와 함께 아파트에서 노숙자로 전락하는 등 어려움을 겪지만, 끝내 성공을 거둡니다.
#
# 이 영화는 실제 크리스 가드너의 자전적 이야기를 바탕으로 하며, 그의 인생 역경을 극복하는 과정을 통해 희망과 용기를 주는 메시지를 전달합니다.
#
# 주연을 맡은 윌 스미스는 이 영화로 아카데미 남우주연상을 수상했습니다.

# %%
# 체인 2: 줄거리 요약 (입력: 영화 제목 → 출력: 줄거리)
chain2 = (
    {"movie": chain1}  # chain1의 출력을 movie 변수로 전달
    | prompt2
    | llm
    | StrOutputParser()
)
print(chain2)

# 실행: "SF" 장르의 영화 추천 및 줄거리 요약
response = chain2.invoke({"genre": "Drama"})
print("\n🔹 영화 줄거리 요약:\n", response)

# %% [markdown]
# ##### chain1과 chain2에서 영화 제목이 일관되게 전달 되도록 변경

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# Step 1: 사용자가 입력한 장르에 따라 영화 추천
prompt1 = ChatPromptTemplate.from_template("{genre} 장르에서 추천할 만한 영화를 한 편 알려주세요.")

# Step 2: 추천된 영화의 줄거리를 요약
prompt2 = ChatPromptTemplate.from_template("{movie} 추천한 영화의 제목을 먼저 알려주시고, 줄을 바꾸어서 영화의 줄거리를 5문장으로 요약해 주세요.")

# OpenAI 모델 사용
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# 체인 1: 영화 추천 (입력: 장르 → 출력: 영화 제목)
chain1 = prompt1 | llm | StrOutputParser()

# 체인 2: 줄거리 요약 (입력: 영화 제목 → 출력: 줄거리)
chain2 = (
    {"movie": chain1}  # chain1의 출력을 movie 변수로 전달
    | prompt2
    | llm
    | StrOutputParser()
)

# 실행: "Drama" 장르의 영화 추천 및 줄거리 요약
response = chain2.invoke({"genre": "Drama"})
print("\n🔹 영화 줄거리 요약:\n", response)
# Out:
# 🔹 영화 줄거리 요약:
#  영화 제목은 **'에브리 바디'**입니다.
#
# 영화는 2023년에 개봉한 미국의 블랙 코미디 드라마 영화입니다. 이 영화는 죽음의 수용소에서 살아남은 두 남자가 우연히 만나면서 벌어지는 이야기를 담고 있습니다. 두 남자는 인생의 허무함과 인간 존재의 의미에 대해 깊은 성찰을 하게 됩니다. 영화는 웃음과 감동을 동시에 선사하며, 두 주연 배우의 연기와 케미가 돋보입니다. 따라서, 드라마 장르에서 추천할 만한 영화를 찾고 계신다면 **'에브리 바디'**를 추천해 드립니다.
