# %%
import os
import time
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI 

# 환경변수 로드
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# LLM 모델 설정
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    temperature=0.7
)
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x00000219DCB80050> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000219DCF7AC90> root_client=<openai.OpenAI object at 0x00000219DC93B470> root_async_client=<openai.AsyncOpenAI object at 0x00000219DCB81D60> model_name='meta-llama/llama-4-scout-17b-16e-instruct' temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://api.groq.com/openai/v1'

# %%
print("="*60)
print("프롬프트 개선 전후 비교 분석")
print("="*60)

# 분석할 주제
topic = "머신러닝"

# ========================================
# 1. 기본 프롬프트 (개선 전)
# ========================================
print("\n 기본 프롬프트 (개선 전)")
print("-" * 40)

# 기본 프롬프트 생성
basic_prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 도움이 되는 AI 어시스턴트입니다."),
    ("user", "{topic}에 대해 설명해주세요.")
])

print(" 기본 프롬프트 구조:")
print(basic_prompt)

# 기본 프롬프트 포맷팅
basic_prompt_text = basic_prompt.format(topic=topic)
print(f"\n 실제 전송 메시지:\n{basic_prompt_text}")

# 기본 프롬프트 실행
print("\n 기본 프롬프트 실행 중...")
start_time = time.time()

try:
    basic_response = llm.invoke(basic_prompt_text)
    basic_time = time.time() - start_time
    
    print(f"\n 기본 프롬프트 응답 (소요시간: {basic_time:.2f}초):")
    print("-" * 30)
    print(basic_response.content)
    
    # 기본 응답 분석
    basic_length = len(basic_response.content)
    basic_word_count = len(basic_response.content.split())
    print(f"\n 기본 응답 분석:")
    print(f"   - 응답 길이: {basic_length}자")
    print(f"   - 단어 수: {basic_word_count}개")
    print(f"   - 소요 시간: {basic_time:.2f}초")
    
except Exception as e:
    print(f" 기본 프롬프트 오류: {e}")
    basic_response = None
    basic_time = 0
    basic_length = 0
    basic_word_count = 0
# Out:
# ============================================================
# 프롬프트 개선 전후 비교 분석
# ============================================================
#
#  기본 프롬프트 (개선 전)
# ----------------------------------------
#  기본 프롬프트 구조:
# input_variables=['topic'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 도움이 되는 AI 어시스턴트입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic}에 대해 설명해주세요.'), additional_kwargs={})]
#
#  실제 전송 메시지:
# System: 당신은 도움이 되는 AI 어시스턴트입니다.
# Human: 머신러닝에 대해 설명해주세요.
#
#  기본 프롬프트 실행 중...
#
#  기본 프롬프트 응답 (소요시간: 1.95초):
# ------------------------------
# 머신러닝은 인공지능(AI)의 한 분야로, 컴퓨터가 데이터를 학습하고 예측하거나 결정을 내릴 수 있도록 하는 기술입니다. 머신러닝은 전통적인 프로그래밍 방식과 달리, 컴퓨터가 스스로 데이터를 분석하고 학습하여 패턴을 발견하고 예측을 합니다.
#
# 머신러닝의 기본 개념은 데이터를 학습하여 모델을 만들고, 이 모델을 사용하여 새로운 데이터에 대한 예측이나 분류를 하는 것입니다. 이러한 학습 과정은 크게 세 가지로 나눌 수 있습니다.
#
# 1. **감독 학습(Supervised Learning)**: 레이블이 지정된 데이터를 사용하여 모델을 학습하는 방식입니다. 예를 들어, 이미지 분류 문제에서 이미지에 대한 레이블(예: 고양이, 강아지)을 제공하고 모델이 이미지를 학습하여 새로운 이미지에 대한 분류를 수행하도록 합니다.
#
# 2. **비감독 학습(Unsupervised Learning)**: 레이블이 지정되지 않은 데이터를 사용하여 모델을 학습하는 방식입니다. 이 경우, 모델은 데이터에서 패턴이나 구조를 스스로 찾아냅니다. 클러스터링이나 차원 축소 등이 비감독 학습의 예입니다.
#
# 3. **강화 학습(Reinforcement Learning)**: 에이전트가 환경과 상호작용하면서 보상을 최대화하는 행동을 학습하는 방식입니다. 이 경우, 모델은 시행착오를 통해 최적의 전략을 학습합니다.
#
# 머신러닝의 과정은 다음과 같습니다.
#
# 1. **데이터 수집**: 다양한 소스에서 데이터를 수집합니다.
# 2. **데이터 전처리**: 데이터를 정리하고, 변환하고, 필요한 경우 데이터를 확대하는 등의 작업을 수행합니다.
# 3. **모델 선택**: 문제에 적합한 머신러닝 모델을 선택합니다.
# 4. **모델 훈련**: 선택한 모델에 데이터를 학습시켜 모델을 훈련합니다.
# 5. **모델 평가**: 훈련된 모델의 성능을 평가합니다.
# 6. **모델 배포**: 모델을 실제 환경에 배포하여 사용합니다.
#
# 머신러닝은 다양한 분야에서 활용되고 있습니다. 예를 들어, 이미지 인식, 음성 인식, 자연어 처리, 추천 시스템, 금융 거래 예측, 의료 진단 등 다양한 응용 분야가 있습니다.
#
# 머신러닝의 장점은 다음과 같습니다.
#
# * **데이터로부터 학습**: 머신러닝 모델은 데이터로부터 직접 학습하므로, 복잡한 패턴이나 관계를 발견할 수 있습니다.
# * **자동화**: 머신러닝 모델은 자동으로 학습하고 예측하므로, 수동으로 처리하기 어려운 대량의 데이터를 처리할 수 있습니다.
# * **개선**: 모델은 지속적으로 학습하고 개선되므로, 성능이 향상될 수 있습니다.
#
# 그러나 머신러닝에도 한계와 도전 과제가 있습니다.
#
# * **데이터 품질**: 머신러닝 모델의 성능은 데이터 품질에 크게 의존합니다. 데이터가 부정확하거나 불완전한 경우, 모델의 성능이 저하될 수 있습니다.
# * **모델 해석**: 머신러닝 모델이 어떻게 작동하는지 이해하기 어려울 수 있습니다. 따라서 모델의 해석과 설명이 중요합니다.
# * **윤리**: 머신러닝 모델의 사용은 윤리적인 문제를 제기할 수 있습니다. 예를 들어, 모델이 편향된 데이터를 학습한 경우, 편향된 결과를 생성할 수 있습니다.
#
# 결론적으로, 머신러닝은 데이터를 학습하여 예측이나 결정을 내리는 기술로, 다양한 분야에서 활용되고 있습니다. 그러나 데이터 품질, 모델 해석, 윤리 등의 도전 과제를 해결해야 합니다.
#
#  기본 응답 분석:
#    - 응답 길이: 1629자
#    - 단어 수: 342개
#    - 소요 시간: 1.95초

# %%
# ========================================
# 2. 개선된 프롬프트 (개선 후)
# ========================================
print("\n" + "="*60)
print(" 개선된 프롬프트 (개선 후)")
print("-" * 40)

# 개선된 프롬프트 생성
improved_prompt = ChatPromptTemplate.from_messages([
    ("system", """당신은 친절하고 전문적인 교육 전문가입니다. 
복잡한 개념을 쉽게 설명하는 것이 특기이며, 
학습자가 이해하기 쉽도록 체계적으로 설명합니다."""),
    ("user", """주제: {topic}

다음 구조로 자세히 설명해주세요:

1.  간단한 정의 (한 문장으로)
2.  핵심 특징 3가지
3.  실생활 적용 사례 2가지  
4.  초보자를 위한 학습 팁
5.  향후 전망

각 섹션을 명확히 구분하고, 전문용어는 쉽게 풀어서 설명해주세요.
구체적인 예시를 포함하여 이해하기 쉽게 작성해주세요.""")
])

print(" 개선된 프롬프트 구조:")
print(improved_prompt)

# 개선된 프롬프트 포맷팅
improved_prompt_text = improved_prompt.format(topic=topic)
print(f"\n 실제 전송 메시지:\n{improved_prompt_text}")

# 개선된 프롬프트 실행
print("\n 개선된 프롬프트 실행 중...")
start_time = time.time()

try:
    improved_response = llm.invoke(improved_prompt_text)
    improved_time = time.time() - start_time
    
    print(f"\n 개선된 프롬프트 응답 (소요시간: {improved_time:.2f}초):")
    print("-" * 30)
    print(improved_response.content)
    
    # 개선된 응답 분석
    improved_length = len(improved_response.content)
    improved_word_count = len(improved_response.content.split())
    print(f"\n 개선된 응답 분석:")
    print(f"   - 응답 길이: {improved_length}자")
    print(f"   - 단어 수: {improved_word_count}개")
    print(f"   - 소요 시간: {improved_time:.2f}초")
    
except Exception as e:
    print(f" 개선된 프롬프트 오류: {e}")
    improved_response = None
    improved_time = 0
    improved_length = 0
    improved_word_count = 0
# Out:
# ============================================================
#  개선된 프롬프트 (개선 후)
# ----------------------------------------
#  개선된 프롬프트 구조:
# input_variables=['topic'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 친절하고 전문적인 교육 전문가입니다. \n복잡한 개념을 쉽게 설명하는 것이 특기이며, \n학습자가 이해하기 쉽도록 체계적으로 설명합니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='주제: {topic}\n\n다음 구조로 자세히 설명해주세요:\n\n1.  간단한 정의 (한 문장으로)\n2.  핵심 특징 3가지\n3.  실생활 적용 사례 2가지  \n4.  초보자를 위한 학습 팁\n5.  향후 전망\n\n각 섹션을 명확히 구분하고, 전문용어는 쉽게 풀어서 설명해주세요.\n구체적인 예시를 포함하여 이해하기 쉽게 작성해주세요.'), additional_kwargs={})]
#
#  실제 전송 메시지:
# System: 당신은 친절하고 전문적인 교육 전문가입니다.
# 복잡한 개념을 쉽게 설명하는 것이 특기이며,
# 학습자가 이해하기 쉽도록 체계적으로 설명합니다.
# Human: 주제: 머신러닝
#
# 다음 구조로 자세히 설명해주세요:
#
# 1.  간단한 정의 (한 문장으로)
# 2.  핵심 특징 3가지
# 3.  실생활 적용 사례 2가지
# 4.  초보자를 위한 학습 팁
# 5.  향후 전망
#
# 각 섹션을 명확히 구분하고, 전문용어는 쉽게 풀어서 설명해주세요.
# 구체적인 예시를 포함하여 이해하기 쉽게 작성해주세요.
#
#  개선된 프롬프트 실행 중...
#
#  개선된 프롬프트 응답 (소요시간: 1.74초):
# ------------------------------
# ## 1. 간단한 정의
#
# 머신러닝은 컴퓨터가 데이터를 분석하고 학습하여 스스로 결정을 내릴 수 있도록 하는 인공지능(AI)의 한 분야입니다.
#
# ## 2. 핵심 특징 3가지
#
# 1. **데이터 의존성**: 머신러닝 알고리즘은 대량의 데이터를 필요로 합니다. 이 데이터를 통해 컴퓨터는 패턴을 인식하고 학습합니다. 예를 들어, 이미지 인식 알고리즘은 수백만 장의 이미지를 학습하여 사물을 식별할 수 있습니다.
#
# 2. **자동화**: 머신러닝은 컴퓨터가 자동으로 학습하고 개선할 수 있도록 합니다. 즉, 사람의 개입 없이도 컴퓨터가 데이터를 분석하고 더 나은 결정을 내릴 수 있습니다. 예를 들어, 스팸 이메일 필터는 새로운 스팸 이메일을 지속적으로 학습하여 차단합니다.
#
# 3. **예측 및 분류**: 머신러닝의 주요 목적 중 하나는 예측과 분류입니다. 예를 들어, 제품 추천 시스템은 사용자의 과거 구매 데이터를 분석하여 향후 구매 가능성이 높은 제품을 추천합니다.
#
# ## 3. 실생활 적용 사례 2가지
#
# 1. **음성 인식**: 머신러닝은 음성 인식 기술에 널리 사용됩니다. 예를 들어, 스마트폰의 가상 비서인 Siri나 Google Assistant는 사용자의 음성 명령을 인식하고 적절한 응답을 제공합니다. 이러한 시스템은 방대한 음성 데이터를 학습하여 정확도를 높입니다.
#
# 2. **추천 시스템**: 온라인 쇼핑 플랫폼이나 스트리밍 서비스는 머신러닝을 활용하여 사용자에게 맞춤형 추천을 제공합니다. 예를 들어, 넷플릭스는 사용자의 시청 기록을 분석하여 비슷한 취향의 다른 사용자가 좋아할 만한 콘텐츠를 추천합니다.
#
# ## 4. 초보자를 위한 학습 팁
#
# - **기초 수학 이해**: 머신러닝은 선형 대수, 미적분, 확률론 등의 수학적 개념을 기반으로 합니다. 이러한 기초 수학을 이해하는 것이 중요합니다.
#
# - **프로그래밍 언어 학습**: 파이썬은 머신러닝에서 널리 사용되는 언어입니다. 파이썬의 기본 문법을 익히고, 텐서플로우(TensorFlow)나 사이킷-런(SciKit-learn) 같은 라이브러리를 학습하세요.
#
# - **실습 프로젝트 진행**: 이론만으로는 머신러닝을 깊이 있게 이해하기 어렵습니다. 간단한 프로젝트부터 시작하여 직접 데이터를 분석하고 모델을 구축해 보세요.
#
# ## 5. 향후 전망
#
# 머신러닝은 빠르게 발전하고 있으며, 다양한 산업 분야에서 그 응용 범위가 넓어지고 있습니다. 향후에는 자율 주행 자동차, 의료 진단, 스마트 홈 시스템 등 더 많은 영역에서 머신러닝 기술이 핵심적인 역할을 할 것으로 예상됩니다. 특히, 데이터의 양이 증가하고 컴퓨팅 능력이 향상됨에 따라 머신러닝 모델의 정확도와 효율성이 더욱 개선될 것입니다.
#
# 머신러닝은 우리의 일상생활을 더욱 편리하고 스마트하게 만들어 줄 잠재력을 가지고 있습니다. 관심 있는 분들은 적극적으로 학습하고, 다양한 프로젝트에 도전해 보기를 권장합니다.
#
#  개선된 응답 분석:
#    - 응답 길이: 1416자
#    - 단어 수: 315개
#    - 소요 시간: 1.74초
