# %% [markdown]
# #### LangSmith 기본 예제

# %% [markdown]
# ##### 1) 라이브러리 설치

# %%
#%pip install -q langchain langchain-openai langsmith
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### 2) OpenAI 인증키 설정

# %%
import os
from dotenv import load_dotenv
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# gsk_5

# %% [markdown]
# ##### LangSmith와 LangChain을 활용한 기본 로깅 예제

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langsmith import traceable

# LangSmith API Key 설정
os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING")  # LangSmith 활성화
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")  # API Key 불러오기
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")   # 프로젝트 이름 설정
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")   # EndPoint 설정

# LLM 모델 설정 (OpenAI 사용)
#llm = ChatOpenAI(model="gpt-3.5-turbo")
llm = ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    model="meta-llama/llama-4-scout-17b-16e-instruct",  # Spring AI와 동일한 모델
    temperature=0.7
)

# LangSmith로 실행 추적
@traceable(run_type="chain", name="Simple_Chain")
def ask_question(question: str):

    # 개별 메시지 템플릿 정의
    system_message = SystemMessagePromptTemplate.from_template(
        "당신은 유용한 AI 비서입니다."
    )
    user_message = HumanMessagePromptTemplate.from_template(
        "{question}"
    )

    chat_prompt = ChatPromptTemplate.from_messages([
        system_message,
        user_message,
    ])
    
    messages = chat_prompt.format_messages(question=question)
    response = llm.invoke(messages)

    return response.content

# 테스트 실행
question = "LangGraph와 LangChain의 차이점은 무엇인가요?"
answer = ask_question(question)

# 결과 출력
print("\n🔹 [AI 답변]:")
print(answer)
# Out:
# 🔹 [AI 답변]:
# LangGraph와 LangChain은 모두 언어 모델을 활용하여 애플리케이션을 구축하기 위한 라이브러리이지만, 다른 디자인 철학과 초점을 가지고 있습니다.
#
# LangChain은 언어 모델을 사용하여 애플리케이션을 구축하기 위한 프레임워크로, 여러 언어 모델을 체인처럼 연결하여 강력한 애플리케이션을 만들 수 있습니다. LangChain은 언어 모델을 호출하고, 출력을 처리하고, 여러 작업을 자동화하는 기능을 제공합니다.
#
# 반면, LangGraph는 LangChain을 기반으로 구축된 라이브러리로, 여러 언어 모델을 그래프 구조로 연결하여 더욱 복잡하고 동적인 애플리케이션을 만들 수 있습니다. LangGraph는 LangChain의 기능을 확장하여, 언어 모델 간의 관계를 그래프로 정의하고, 그래프 구조로 애플리케이션을 구축할 수 있습니다.
#
# 즉, LangChain은 언어 모델을 체인처럼 연결하여 애플리케이션을 만드는 라이브러리이고, LangGraph는 언어 모델을 그래프 구조로 연결하여 더욱 복잡하고 동적인 애플리케이션을 만드는 라이브러리입니다.
#
# LangGraph는 LangChain의 상위 호환 라이브러리라고도 할 수 있습니다. LangGraph는 LangChain의 모든 기능을 포함하면서도, 그래프 구조를 지원하여 더욱 복잡한 애플리케이션을 만들 수 있습니다. 따라서, LangGraph를 사용하면 LangChain으로 할 수 있는 모든 것을 할 수 있으며, 추가로 그래프 구조를 활용하여 더욱 동적인 애플리케이션을 만들 수 있습니다.
